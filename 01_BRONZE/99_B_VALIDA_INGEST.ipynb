# %%
# %sql
-- valida se ha nove arquivos ingestados na tabela de logs e sem nenhuma repeticao

-- with tab_valida as (
--     select 
--     count(nm_arquivo_ingest) as qtd_arquivos,
--     count(distinct nm_arquivo_ingest) as qtd_arquivos_distinct
--     from bikestore.default.tb_ingest_log
-- )

-- select 
-- case when (qtd_arquivos = 9 and qtd_arquivos_distinct = 9) then 'ok' else raise_error("Erro na ingestao.") end as status
-- from tab_valida


select 1+1
